# %%
from IPython.display import Image
import os

for fn in os.listdir():
    #print(fn)
    if fn.endswith('png'):
        print(fn)
        display(Image(filename=fn))
# Out:
# Code_Zasd_qb.png
# Code_Zasd_zd.png
# Code_Zasd_cc.png
# Code_Zasd_hsqq.png
# Code_Zasd_blsd.png
# Code_Zasd_xp.png
# Code_Zasd_cm.png
# Code_zatd_stfs.png
# Code_zatd_xwtd.png
# Code_Zasd_pp.png
# Code_zatd_zafw.png
# Code_Zasd_ybsd.png
# Code_zatd_zzxs.png
